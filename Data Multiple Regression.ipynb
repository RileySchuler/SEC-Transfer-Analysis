# %%
from bs4 import BeautifulSoup
import requests
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('raw_sec_player_stats.csv')
df
# Out:
#          player_id             name  year age       team conference   PA  \
# 0     beck--001jor      Jordan Beck  2020  19  Tennessee        SEC   48
# 1     beck--001jor      Jordan Beck  2021  20  Tennessee        SEC  289
# 2     beck--001jor      Jordan Beck  2022  21  Tennessee        SEC  297
# 3     booker000kyl      Kyle Booker  2021  19  Tennessee        SEC   68
# 4     booker000kyl      Kyle Booker  2022  20  Tennessee        SEC   55
# ...            ...              ...   ...  ..        ...        ...  ...
# 1984  patter004chr  Chris Patterson  2025  18   Missouri        SEC  125
# 1985  picare000bra  Brady Picarelli  2025  19   Missouri        SEC   56
# 1986  seals-000pie     Pierre Seals  2024  20    Memphis       Amer  241
# 1987  seals-000pie     Pierre Seals  2025  21   Missouri        SEC  172
# 1988  simpso002bla    Blake Simpson  2025  22   Missouri        SEC   12
#
#         BB  SO    OBP    SLG    OPS
# 0      8.0  11  0.396  0.475  0.871
# 1     24.0  60  0.336  0.523  0.859
# 2     37.0  62  0.391  0.595  0.986
# 3      7.0  18  0.382  0.448  0.831
# 4      7.0  12  0.364  0.356  0.719
# ...    ...  ..    ...    ...    ...
# 1984  10.0  41  0.304  0.393  0.697
# 1985   7.0  15  0.393  0.604  0.997
# 1986  31.0  63  0.436  0.553  0.988
# 1987  17.0  58  0.374  0.446  0.820
# 1988   0.0   0  0.333  0.583  0.917
#
# [1989 rows x 12 columns]

# %%
df['conference'].unique()
# Out:
# array(['SEC', 'SUMT', 'MVC', 'WAC', 'P12', 'ACC', 'SLC', 'Amer', 'BigW',
#        'CUSA', 'B12', 'MAC', 'SBC', 'GLVC', 'SoCo', 'BigS', 'BTen',
#        'ASun', 'SSC', 'CAA', 'MWC', 'OVC', 'AEC', 'MIAA', 'IVY', 'WCC',
#        'CCar', 'GSC', 'A10', 'BigE', 'NE10', 'UAA', 'LSC', 'MEAC', 'SWAC',
#        'SCIA', 'D1IN', 'Horz', 'MAAC', 'PBC', 'CACC', 'SAC', 'SAA',
#        'GNAC', 'AMWC'], dtype=object)

# %%
conference_name_map = {
    "ACC": "ACC",
    "America-East": "AEC",
    "American-Athletic": "Amer",
    "ASUN": "ASun",
    "Atlantic-10": "A10",
    "Big-12": "B12",
    "Big-East": "BigE",
    "Big-South": "BigS",
    "Big-Ten": "BTen",
    "Big-West": "BigW",
    "Coastal-Athletic": "CAA",  # same as Colonial
    "Colonial-Athletic": "CAA",  # same as Coastal
    "Conference-USA": "CUSA",
    "Horizon-League": "Horz",
    "Independent": "D1IN",
    "Ivy-League": "IVY",
    "MAAC": "MAAC",
    "Mid-American": "MAC",
    "Missouri-Valley": "MVC",
    "Mountain-West": "MWC",
    "Northeast": "NEC",  # not in your list — placeholder if needed
    "Ohio-Valley": "OVC",
    "Patriot-League": "Patriot",  # not in your list — placeholder if needed
    "SEC": "SEC",
    "Southern": "SoCo",
    "Southland": "SLC",
    "Sun-Belt": "SBC",
    "SWAC": "SWAC",
    "The-Summit-League": "SUMT",
    "West-Coast": "WCC",
    "Western-Athletic": "WAC",
    "Pac-12": "P12",
    "MEAC": "MEAC"
}

# %%
conf_rpi_map = {
    2021: {},
    2022: {},
    2023: {},
    2024: {}
}

# %%
url = 'https://www.warrennolan.com/baseball/2021/rpi-conference'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

# %%
trs_with_conf_logo = [
    tr for tr in soup.find_all('tr')
    if tr.find('ul', class_='conf-logo') is not None
]


html_snippet = ''.join(str(tr) for tr in trs_with_conf_logo)
sub_soup = BeautifulSoup(html_snippet, 'html.parser')

for conf in sub_soup.find_all('tr'):
    conference = conf.find('a')['class'][0]
    rpi = conf.find_all('td')[2].text
    conf_rpi_map[2021].update({conference_name_map[conference]: rpi})

# %%
conf_rpi_map
# Out:
# {2021: {'SEC': '0.5661',
#   'B12': '0.5584',
#   'ACC': '0.5507',
#   'P12': '0.5430',
#   'Amer': '0.5154',
#   'CUSA': '0.5129',
#   'MVC': '0.5093',
#   'MWC': '0.5054',
#   'SoCo': '0.5046',
#   'SBC': '0.4988',
#   'BTen': '0.4972',
#   'WCC': '0.4950',
#   'BigE': '0.4919',
#   'BigW': '0.4919',
#   'MAAC': '0.4899',
#   'CAA': '0.4875',
#   'OVC': '0.4846',
#   'AEC': '0.4833',
#   'SLC': '0.4819',
#   'BigS': '0.4804',
#   'A10': '0.4769',
#   'ASun': '0.4758',
#   'SUMT': '0.4749',
#   'Horz': '0.4739',
#   'MAC': '0.4731',
#   'WAC': '0.4590',
#   'Patriot': '0.4572',
#   'NEC': '0.4550',
#   'SWAC': '0.4062',
#   'MEAC': '0.3201',
#   'IVY': '0.0610'},
#  2022: {},
#  2023: {},
#  2024: {}}

# %%
url2 = 'https://www.warrennolan.com/baseball/2022/rpi-conference'
page2 = requests.get(url2)
soup2 = BeautifulSoup(page2.text, 'html')

# %%
soup2.find_all('tr')[1:]
# Out:
# [<tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="SEC" href="/baseball/2022/conference/SEC"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/SEC">SEC</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.5760</td>
#  <td class="data-cell data-center data-medium cell-right-black">1</td>
#  <td class="data-cell data-center data-medium">264-76</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.7765</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Tennessee" href="/baseball/2022/schedule/Tennessee"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Tennessee">Tennessee</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">1</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="ACC" href="/baseball/2022/conference/ACC"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/ACC">ACC</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.5672</td>
#  <td class="data-cell data-center data-medium cell-right-black">2</td>
#  <td class="data-cell data-center data-medium">257-77</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.7695</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Virginia-Tech" href="/baseball/2022/schedule/Virginia-Tech"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Virginia-Tech">Virginia Tech</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">10</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="Big-12" href="/baseball/2022/conference/Big-12"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/Big-12">Big 12</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.5556</td>
#  <td class="data-cell data-center data-medium cell-right-black">3</td>
#  <td class="data-cell data-center data-medium">176-91</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.6592</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="TCU" href="/baseball/2022/schedule/TCU"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/TCU">TCU</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">34</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="Pac-12" href="/baseball/2022/conference/Pac-12"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/Pac-12">Pac-12</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.5480</td>
#  <td class="data-cell data-center data-medium cell-right-black">4</td>
#  <td class="data-cell data-center data-medium">178-84</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.6794</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Stanford" href="/baseball/2022/schedule/Stanford"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Stanford">Stanford</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">4</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="Conference-USA" href="/baseball/2022/conference/Conference-USA"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/Conference-USA">Conference USA</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.5222</td>
#  <td class="data-cell data-center data-medium cell-right-black">5</td>
#  <td class="data-cell data-center data-medium">171-117</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.5938</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Southern-Miss" href="/baseball/2022/schedule/Southern-Miss"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Southern-Miss">Southern Miss</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">22</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="Sun-Belt" href="/baseball/2022/conference/Sun-Belt"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/Sun-Belt">Sun Belt</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.5182</td>
#  <td class="data-cell data-center data-medium cell-right-black">6</td>
#  <td class="data-cell data-center data-medium">152-128</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.5429</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Texas-State" href="/baseball/2022/schedule/Texas-State"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Texas-State">Texas State</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">20</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="American-Athletic" href="/baseball/2022/conference/American-Athletic"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/American-Athletic">American Athletic</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.5173</td>
#  <td class="data-cell data-center data-medium cell-right-black">7</td>
#  <td class="data-cell data-center data-medium">136-108</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.5574</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="East-Carolina" href="/baseball/2022/schedule/East-Carolina"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/East-Carolina">East Carolina</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">18</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="Big-Ten" href="/baseball/2022/conference/Big-Ten"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/Big-Ten">Big Ten</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.5166</td>
#  <td class="data-cell data-center data-medium cell-right-black">8</td>
#  <td class="data-cell data-center data-medium">208-161</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.5637</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Maryland" href="/baseball/2022/schedule/Maryland"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Maryland">Maryland</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">13</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="Missouri-Valley" href="/baseball/2022/conference/Missouri-Valley"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/Missouri-Valley">Missouri Valley</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.5145</td>
#  <td class="data-cell data-center data-medium cell-right-black">9</td>
#  <td class="data-cell data-center data-medium">127-108</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.5404</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Southern-Illinois" href="/baseball/2022/schedule/Southern-Illinois"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Southern-Illinois">Southern Illinois</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">65</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="Southern" href="/baseball/2022/conference/Southern"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/Southern">Southern</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.5052</td>
#  <td class="data-cell data-center data-medium cell-right-black">10</td>
#  <td class="data-cell data-center data-medium">146-118</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.5530</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Wofford" href="/baseball/2022/schedule/Wofford"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Wofford">Wofford</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">37</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="West-Coast" href="/baseball/2022/conference/West-Coast"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/West-Coast">West Coast</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.5048</td>
#  <td class="data-cell data-center data-medium cell-right-black">11</td>
#  <td class="data-cell data-center data-medium">129-122</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.5139</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Gonzaga" href="/baseball/2022/schedule/Gonzaga"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Gonzaga">Gonzaga</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">31</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="Colonial-Athletic" href="/baseball/2022/conference/Colonial-Athletic"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/Colonial-Athletic">Colonial Athletic</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.5037</td>
#  <td class="data-cell data-center data-medium cell-right-black">12</td>
#  <td class="data-cell data-center data-medium">132-120</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.5238</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Charleston" href="/baseball/2022/schedule/Charleston"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Charleston">Charleston</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">67</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="Big-East" href="/baseball/2022/conference/Big-East"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/Big-East">Big East</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.5021</td>
#  <td class="data-cell data-center data-medium cell-right-black">13</td>
#  <td class="data-cell data-center data-medium">133-126</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.5135</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Connecticut" href="/baseball/2022/schedule/Connecticut"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Connecticut">Connecticut</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">26</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="Mountain-West" href="/baseball/2022/conference/Mountain-West"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/Mountain-West">Mountain West</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.4943</td>
#  <td class="data-cell data-center data-medium cell-right-black">14</td>
#  <td class="data-cell data-center data-medium">80-92</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.4651</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="UNLV" href="/baseball/2022/schedule/UNLV"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/UNLV">UNLV</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">111</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="ASUN" href="/baseball/2022/conference/ASUN"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/ASUN">ASUN</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.4933</td>
#  <td class="data-cell data-center data-medium cell-right-black">15</td>
#  <td class="data-cell data-center data-medium">135-151</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.4720</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Eastern-Kentucky" href="/baseball/2022/schedule/Eastern-Kentucky"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Eastern-Kentucky">Eastern Kentucky</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">115</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="Ohio-Valley" href="/baseball/2022/conference/Ohio-Valley"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/Ohio-Valley">Ohio Valley</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.4924</td>
#  <td class="data-cell data-center data-medium cell-right-black">16</td>
#  <td class="data-cell data-center data-medium">132-120</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.5238</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Belmont" href="/baseball/2022/schedule/Belmont"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Belmont">Belmont</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">63</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="Ivy-League" href="/baseball/2022/conference/Ivy-League"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/Ivy-League">Ivy League</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.4889</td>
#  <td class="data-cell data-center data-medium cell-right-black">17</td>
#  <td class="data-cell data-center data-medium">67-84</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.4437</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Penn" href="/baseball/2022/schedule/Penn"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Penn">Penn</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">56</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="Southland" href="/baseball/2022/conference/Southland"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/Southland">Southland</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.4857</td>
#  <td class="data-cell data-center data-medium cell-right-black">18</td>
#  <td class="data-cell data-center data-medium">97-112</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.4641</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="McNeese" href="/baseball/2022/schedule/McNeese"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/McNeese">McNeese</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">165</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="Western-Athletic" href="/baseball/2022/conference/Western-Athletic"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/Western-Athletic">Western Athletic</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.4840</td>
#  <td class="data-cell data-center data-medium cell-right-black">19</td>
#  <td class="data-cell data-center data-medium">140-164</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.4605</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Grand-Canyon" href="/baseball/2022/schedule/Grand-Canyon"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Grand-Canyon">Grand Canyon</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">55</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="Big-West" href="/baseball/2022/conference/Big-West"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/Big-West">Big West</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.4820</td>
#  <td class="data-cell data-center data-medium cell-right-black">20</td>
#  <td class="data-cell data-center data-medium">114-144</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.4419</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="UC-Santa-Barbara" href="/baseball/2022/schedule/UC-Santa-Barbara"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/UC-Santa-Barbara">UC Santa Barbara</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">48</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="Atlantic-10" href="/baseball/2022/conference/Atlantic-10"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/Atlantic-10">Atlantic 10</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.4723</td>
#  <td class="data-cell data-center data-medium cell-right-black">21</td>
#  <td class="data-cell data-center data-medium">146-177</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.4520</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Davidson" href="/baseball/2022/schedule/Davidson"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Davidson">Davidson</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">71</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="Mid-American" href="/baseball/2022/conference/Mid-American"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/Mid-American">Mid-American</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.4703</td>
#  <td class="data-cell data-center data-medium cell-right-black">22</td>
#  <td class="data-cell data-center data-medium">55-111</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.3313</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Ball-State" href="/baseball/2022/schedule/Ball-State"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Ball-State">Ball State</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">72</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="Big-South" href="/baseball/2022/conference/Big-South"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/Big-South">Big South</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.4691</td>
#  <td class="data-cell data-center data-medium cell-right-black">23</td>
#  <td class="data-cell data-center data-medium">115-196</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.3698</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Campbell" href="/baseball/2022/schedule/Campbell"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Campbell">Campbell</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">59</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="America-East" href="/baseball/2022/conference/America-East"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/America-East">America East</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.4615</td>
#  <td class="data-cell data-center data-medium cell-right-black">24</td>
#  <td class="data-cell data-center data-medium">57-96</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.3725</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Maine" href="/baseball/2022/schedule/Maine"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Maine">Maine</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">167</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="Horizon-League" href="/baseball/2022/conference/Horizon-League"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/Horizon-League">Horizon League</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.4566</td>
#  <td class="data-cell data-center data-medium cell-right-black">25</td>
#  <td class="data-cell data-center data-medium">51-109</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.3187</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Wright-State" href="/baseball/2022/schedule/Wright-State"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Wright-State">Wright State</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">143</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="Northeast" href="/baseball/2022/conference/Northeast"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/Northeast">Northeast</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.4516</td>
#  <td class="data-cell data-center data-medium cell-right-black">26</td>
#  <td class="data-cell data-center data-medium">65-119</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.3533</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Long-Island" href="/baseball/2022/schedule/Long-Island"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Long-Island">Long Island</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">131</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="Patriot-League" href="/baseball/2022/conference/Patriot-League"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/Patriot-League">Patriot League</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.4511</td>
#  <td class="data-cell data-center data-medium cell-right-black">27</td>
#  <td class="data-cell data-center data-medium">47-89</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.3456</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Army" href="/baseball/2022/schedule/Army"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Army">Army</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">156</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="MAAC" href="/baseball/2022/conference/MAAC"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/MAAC">MAAC</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.4502</td>
#  <td class="data-cell data-center data-medium cell-right-black">28</td>
#  <td class="data-cell data-center data-medium">91-187</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.3273</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Fairfield" href="/baseball/2022/schedule/Fairfield"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Fairfield">Fairfield</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">147</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="The-Summit-League" href="/baseball/2022/conference/The-Summit-League"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/The-Summit-League">The Summit League</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.4448</td>
#  <td class="data-cell data-center data-medium cell-right-black">29</td>
#  <td class="data-cell data-center data-medium">58-111</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.3432</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="North-Dakota-State" href="/baseball/2022/schedule/North-Dakota-State"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/North-Dakota-State">North Dakota State</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">129</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="SWAC" href="/baseball/2022/conference/SWAC"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/SWAC">SWAC</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.4102</td>
#  <td class="data-cell data-center data-medium cell-right-black">30</td>
#  <td class="data-cell data-center data-medium">50-172</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.2252</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Alabama-State" href="/baseball/2022/schedule/Alabama-State"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Alabama-State">Alabama State</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">187</td>
#  </tr>,
#  <tr>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="conf-logo"><li><a class="MEAC" href="/baseball/2022/conference/MEAC"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/conference/MEAC">MEAC</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">0.4028</td>
#  <td class="data-cell data-center data-medium cell-right-black">31</td>
#  <td class="data-cell data-center data-medium">11-50</td>
#  <td class="data-cell data-center data-medium cell-right-black">0.1803</td>
#  <td class="data-cell data-medium">
#  <div class="logo-name-container">
#  <div class="logo-subcontainer"><ul class="team-logo"><li><a class="Delaware-State" href="/baseball/2022/schedule/Delaware-State"></a></li></ul></div>
#  <div class="name-subcontainer"><a class="blue-black" href="/baseball/2022/schedule/Delaware-State">Delaware State</a></div>
#  </div>
#  </td>
#  <td class="data-cell data-center data-medium">272</td>
#  </tr>]

# %%
for conf in soup2.find_all('tr')[1:]:
    conference = conf.find('a')['class'][0]
    rpi = conf.find_all('td', 'data-cell data-center data-medium')[0].text
    conf_rpi_map[year].update({conference_name_map[conference]: rpi})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       2 conference = conf.find('a')['class'][0]
#       3 rpi = conf.find_all('td', 'data-cell data-center data-medium')[0].text
# ----> 4 conf_rpi_map[year].update({conference_name_map[conference]: rpi})
#
# NameError: name 'year' is not defined

# %%
for year in range(2022,2025):
    url = 'https://www.warrennolan.com/baseball/' + str(year) + '/rpi-conference'
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html')

    for conf in soup.find_all('tr')[1:]:
        conference = conf.find('a')['class'][0]
        rpi = conf.find_all('td', 'data-cell data-center data-medium')[0].text
        conf_rpi_map[year].update({conference_name_map[conference]: rpi})
    
    time.sleep(5)

# %%
conf_rpi_map
# Out:
# {2021: {'SEC': '0.5661',
#   'B12': '0.5584',
#   'ACC': '0.5507',
#   'P12': '0.5430',
#   'Amer': '0.5154',
#   'CUSA': '0.5129',
#   'MVC': '0.5093',
#   'MWC': '0.5054',
#   'SoCo': '0.5046',
#   'SBC': '0.4988',
#   'BTen': '0.4972',
#   'WCC': '0.4950',
#   'BigE': '0.4919',
#   'BigW': '0.4919',
#   'MAAC': '0.4899',
#   'CAA': '0.4875',
#   'OVC': '0.4846',
#   'AEC': '0.4833',
#   'SLC': '0.4819',
#   'BigS': '0.4804',
#   'A10': '0.4769',
#   'ASun': '0.4758',
#   'SUMT': '0.4749',
#   'Horz': '0.4739',
#   'MAC': '0.4731',
#   'WAC': '0.4590',
#   'Patriot': '0.4572',
#   'NEC': '0.4550',
#   'SWAC': '0.4062',
#   'MEAC': '0.3201',
#   'IVY': '0.0610'},
#  2022: {'SEC': '0.5760',
#   'ACC': '0.5672',
#   'B12': '0.5556',
#   'P12': '0.5480',
#   'CUSA': '0.5222',
#   'SBC': '0.5182',
#   'Amer': '0.5173',
#   'BTen': '0.5166',
#   'MVC': '0.5145',
#   'SoCo': '0.5052',
#   'WCC': '0.5048',
#   'CAA': '0.5037',
#   'BigE': '0.5021',
#   'MWC': '0.4943',
#   'ASun': '0.4933',
#   'OVC': '0.4924',
#   'IVY': '0.4889',
#   'SLC': '0.4857',
#   'WAC': '0.4840',
#   'BigW': '0.4820',
#   'A10': '0.4723',
#   'MAC': '0.4703',
#   'BigS': '0.4691',
#   'AEC': '0.4615',
#   'Horz': '0.4566',
#   'NEC': '0.4516',
#   'Patriot': '0.4511',
#   'MAAC': '0.4502',
#   'SUMT': '0.4448',
#   'SWAC': '0.4102',
#   'MEAC': '0.4028'},
#  2023: {'SEC': '0.5875',
#   'ACC': '0.5724',
#   'B12': '0.5559',
#   'P12': '0.5495',
#   'SBC': '0.5223',
#   'BTen': '0.5201',
#   'CAA': '0.5146',
#   'CUSA': '0.5139',
#   'Amer': '0.5114',
#   'BigW': '0.5103',
#   'MVC': '0.5068',
#   'BigE': '0.5031',
#   'SoCo': '0.4963',
#   'SLC': '0.4962',
#   'BigS': '0.4860',
#   'WAC': '0.4854',
#   'ASun': '0.4843',
#   'WCC': '0.4838',
#   'MWC': '0.4836',
#   'MAC': '0.4805',
#   'AEC': '0.4714',
#   'OVC': '0.4638',
#   'Horz': '0.4614',
#   'A10': '0.4596',
#   'Patriot': '0.4588',
#   'MAAC': '0.4556',
#   'IVY': '0.4521',
#   'SUMT': '0.4444',
#   'NEC': '0.4272',
#   'SWAC': '0.4171',
#   'D1IN': '0.3843'},
#  2024: {'SEC': '0.5886',
#   'ACC': '0.5686',
#   'B12': '0.5496',
#   'BTen': '0.5332',
#   'SBC': '0.5309',
#   'P12': '0.5276',
#   'BigE': '0.5244',
#   'SoCo': '0.5200',
#   'CUSA': '0.5165',
#   'CAA': '0.5099',
#   'MVC': '0.5087',
#   'Amer': '0.5065',
#   'BigW': '0.5053',
#   'SLC': '0.4968',
#   'A10': '0.4875',
#   'WCC': '0.4850',
#   'Patriot': '0.4788',
#   'MWC': '0.4777',
#   'BigS': '0.4758',
#   'MAC': '0.4709',
#   'WAC': '0.4700',
#   'ASun': '0.4675',
#   'Horz': '0.4623',
#   'OVC': '0.4588',
#   'IVY': '0.4584',
#   'AEC': '0.4576',
#   'MAAC': '0.4443',
#   'SUMT': '0.4420',
#   'NEC': '0.4329',
#   'SWAC': '0.4181'}}

# %%
conf_rpi_map.update({2025: {'SEC': 0.5858}})

# %%
conf_rpi_map
# Out:
# {2021: {'SEC': '0.5661',
#   'B12': '0.5584',
#   'ACC': '0.5507',
#   'P12': '0.5430',
#   'Amer': '0.5154',
#   'CUSA': '0.5129',
#   'MVC': '0.5093',
#   'MWC': '0.5054',
#   'SoCo': '0.5046',
#   'SBC': '0.4988',
#   'BTen': '0.4972',
#   'WCC': '0.4950',
#   'BigE': '0.4919',
#   'BigW': '0.4919',
#   'MAAC': '0.4899',
#   'CAA': '0.4875',
#   'OVC': '0.4846',
#   'AEC': '0.4833',
#   'SLC': '0.4819',
#   'BigS': '0.4804',
#   'A10': '0.4769',
#   'ASun': '0.4758',
#   'SUMT': '0.4749',
#   'Horz': '0.4739',
#   'MAC': '0.4731',
#   'WAC': '0.4590',
#   'Patriot': '0.4572',
#   'NEC': '0.4550',
#   'SWAC': '0.4062',
#   'MEAC': '0.3201',
#   'IVY': '0.0610'},
#  2022: {'SEC': '0.5760',
#   'ACC': '0.5672',
#   'B12': '0.5556',
#   'P12': '0.5480',
#   'CUSA': '0.5222',
#   'SBC': '0.5182',
#   'Amer': '0.5173',
#   'BTen': '0.5166',
#   'MVC': '0.5145',
#   'SoCo': '0.5052',
#   'WCC': '0.5048',
#   'CAA': '0.5037',
#   'BigE': '0.5021',
#   'MWC': '0.4943',
#   'ASun': '0.4933',
#   'OVC': '0.4924',
#   'IVY': '0.4889',
#   'SLC': '0.4857',
#   'WAC': '0.4840',
#   'BigW': '0.4820',
#   'A10': '0.4723',
#   'MAC': '0.4703',
#   'BigS': '0.4691',
#   'AEC': '0.4615',
#   'Horz': '0.4566',
#   'NEC': '0.4516',
#   'Patriot': '0.4511',
#   'MAAC': '0.4502',
#   'SUMT': '0.4448',
#   'SWAC': '0.4102',
#   'MEAC': '0.4028'},
#  2023: {'SEC': '0.5875',
#   'ACC': '0.5724',
#   'B12': '0.5559',
#   'P12': '0.5495',
#   'SBC': '0.5223',
#   'BTen': '0.5201',
#   'CAA': '0.5146',
#   'CUSA': '0.5139',
#   'Amer': '0.5114',
#   'BigW': '0.5103',
#   'MVC': '0.5068',
#   'BigE': '0.5031',
#   'SoCo': '0.4963',
#   'SLC': '0.4962',
#   'BigS': '0.4860',
#   'WAC': '0.4854',
#   'ASun': '0.4843',
#   'WCC': '0.4838',
#   'MWC': '0.4836',
#   'MAC': '0.4805',
#   'AEC': '0.4714',
#   'OVC': '0.4638',
#   'Horz': '0.4614',
#   'A10': '0.4596',
#   'Patriot': '0.4588',
#   'MAAC': '0.4556',
#   'IVY': '0.4521',
#   'SUMT': '0.4444',
#   'NEC': '0.4272',
#   'SWAC': '0.4171',
#   'D1IN': '0.3843'},
#  2024: {'SEC': '0.5886',
#   'ACC': '0.5686',
#   'B12': '0.5496',
#   'BTen': '0.5332',
#   'SBC': '0.5309',
#   'P12': '0.5276',
#   'BigE': '0.5244',
#   'SoCo': '0.5200',
#   'CUSA': '0.5165',
#   'CAA': '0.5099',
#   'MVC': '0.5087',
#   'Amer': '0.5065',
#   'BigW': '0.5053',
#   'SLC': '0.4968',
#   'A10': '0.4875',
#   'WCC': '0.4850',
#   'Patriot': '0.4788',
#   'MWC': '0.4777',
#   'BigS': '0.4758',
#   'MAC': '0.4709',
#   'WAC': '0.4700',
#   'ASun': '0.4675',
#   'Horz': '0.4623',
#   'OVC': '0.4588',
#   'IVY': '0.4584',
#   'AEC': '0.4576',
#   'MAAC': '0.4443',
#   'SUMT': '0.4420',
#   'NEC': '0.4329',
#   'SWAC': '0.4181'},
#  2025: {'SEC': 0.5858}}

# %%
mreg_df = pd.read_csv('player_comparison.csv')

# %%
mreg_df
# Out:
#         player_id  prev year  next year class transition       type prev conf  \
# 0    beck--001jor       2021       2022           2 to 3  Returning       SEC
# 1    burke-000bla       2023       2024           2 to 3  Returning       SEC
# 2    ensley000hun       2023       2024           3 to 4  Returning       SEC
# 3    ensley000hun       2024       2025           4 to 5  Returning       SEC
# 4    gilber002and       2021       2022           2 to 3  Returning       SEC
# ..            ...        ...        ...              ...        ...       ...
# 245  sulliv000noa       2024       2025           3 to 4   Transfer      BigS
# 246  hage--000col       2024       2025           3 to 4   Transfer       IVY
# 247  lawren001luk       2024       2025           2 to 3   Transfer       MVC
# 248  hensel000wya       2024       2025           4 to 5   Transfer       IVY
# 249  kaczma000hen       2024       2025           2 to 3   Transfer      BTen
#
#     next conf  prev BB%  next BB%  prev K%  next K%  prev OBP  next OBP  \
# 0         SEC       8.3      12.5     20.8     20.9     0.336     0.391
# 1         SEC       9.2      10.8     17.4     14.9     0.369     0.449
# 2         SEC      10.3      10.7     18.5     19.0     0.391     0.390
# 3         SEC      10.7      10.6     19.0     14.9     0.390     0.418
# 4         SEC       5.0      13.5     13.2     13.1     0.341     0.455
# ..        ...       ...       ...      ...      ...       ...       ...
# 245       SEC      14.5      13.7     12.1     16.5     0.453     0.475
# 246       SEC      13.2      11.9     13.7     15.1     0.471     0.444
# 247       SEC       8.4       7.5     13.6     12.7     0.399     0.397
# 248       SEC      11.4       7.5     11.4     16.2     0.465     0.423
# 249       SEC      11.3      10.6     16.6     20.7     0.417     0.394
#
#      prev SLG  next SLG  prev OPS  next OPS
# 0       0.523     0.595     0.859     0.986
# 1       0.527     0.702     0.896     1.151
# 2       0.425     0.532     0.816     0.923
# 3       0.532     0.531     0.923     0.950
# 4       0.437     0.673     0.778     1.128
# ..        ...       ...       ...       ...
# 245     0.613     0.645     1.066     1.120
# 246     0.658     0.574     1.129     1.019
# 247     0.465     0.425     0.864     0.822
# 248     0.755     0.562     1.220     0.985
# 249     0.476     0.486     0.892     0.880
#
# [250 rows x 17 columns]

# %%
mreg_df[mreg_df['type'] == 'Returning'][['prev BB%','prev K%', 'prev OBP', 'prev SLG', 'next BB%']].corr()['next BB%']
# Out:
# prev BB%    0.452738
# prev K%     0.080261
# prev OBP    0.370612
# prev SLG    0.365454
# next BB%    1.000000
# Name: next BB%, dtype: float64

# %%
mreg_df = pd.get_dummies(mreg_df, columns=['class transition'], drop_first=True)

# %%
def compute_conf_jump(row):
    prev_score = conf_rpi_map[row['prev year']][row['prev conf']]
    next_score = conf_rpi_map[row['next year']][row['next conf']]
    return float(next_score) - float(prev_score)

# %%
mreg_df['conf jump score'] = mreg_df.apply(compute_conf_jump, axis=1)

# %%
mreg_df
# Out:
#         player_id  prev year  next year       type prev conf next conf  \
# 0    beck--001jor       2021       2022  Returning       SEC       SEC
# 1    burke-000bla       2023       2024  Returning       SEC       SEC
# 2    ensley000hun       2023       2024  Returning       SEC       SEC
# 3    ensley000hun       2024       2025  Returning       SEC       SEC
# 4    gilber002and       2021       2022  Returning       SEC       SEC
# ..            ...        ...        ...        ...       ...       ...
# 245  sulliv000noa       2024       2025   Transfer      BigS       SEC
# 246  hage--000col       2024       2025   Transfer       IVY       SEC
# 247  lawren001luk       2024       2025   Transfer       MVC       SEC
# 248  hensel000wya       2024       2025   Transfer       IVY       SEC
# 249  kaczma000hen       2024       2025   Transfer      BTen       SEC
#
#      prev BB%  next BB%  prev K%  next K%  ...  next OBP  prev SLG  next SLG  \
# 0         8.3      12.5     20.8     20.9  ...     0.391     0.523     0.595
# 1         9.2      10.8     17.4     14.9  ...     0.449     0.527     0.702
# 2        10.3      10.7     18.5     19.0  ...     0.390     0.425     0.532
# 3        10.7      10.6     19.0     14.9  ...     0.418     0.532     0.531
# 4         5.0      13.5     13.2     13.1  ...     0.455     0.437     0.673
# ..        ...       ...      ...      ...  ...       ...       ...       ...
# 245      14.5      13.7     12.1     16.5  ...     0.475     0.613     0.645
# 246      13.2      11.9     13.7     15.1  ...     0.444     0.658     0.574
# 247       8.4       7.5     13.6     12.7  ...     0.397     0.465     0.425
# 248      11.4       7.5     11.4     16.2  ...     0.423     0.755     0.562
# 249      11.3      10.6     16.6     20.7  ...     0.394     0.476     0.486
#
#      prev OPS  next OPS  conf jump score  class transition_2 to 3  \
# 0       0.859     0.986           0.0099                     True
# 1       0.896     1.151           0.0011                     True
# 2       0.816     0.923           0.0011                    False
# 3       0.923     0.950          -0.0028                    False
# 4       0.778     1.128           0.0099                     True
# ..        ...       ...              ...                      ...
# 245     1.066     1.120           0.1100                    False
# 246     1.129     1.019           0.1274                    False
# 247     0.864     0.822           0.0771                     True
# 248     1.220     0.985           0.1274                    False
# 249     0.892     0.880           0.0526                     True
#
#      class transition_3 to 4  class transition_4 to 5  class transition_5 to 6
# 0                      False                    False                    False
# 1                      False                    False                    False
# 2                       True                    False                    False
# 3                      False                     True                    False
# 4                      False                    False                    False
# ..                       ...                      ...                      ...
# 245                     True                    False                    False
# 246                     True                    False                    False
# 247                    False                    False                    False
# 248                    False                     True                    False
# 249                    False                    False                    False
#
# [250 rows x 21 columns]

# %%
mreg_df = pd.get_dummies(mreg_df, columns=['type'], drop_first=True)

# %%
mreg_df
# Out:
#         player_id  prev year  next year prev conf next conf  prev BB%  \
# 0    beck--001jor       2021       2022       SEC       SEC       8.3
# 1    burke-000bla       2023       2024       SEC       SEC       9.2
# 2    ensley000hun       2023       2024       SEC       SEC      10.3
# 3    ensley000hun       2024       2025       SEC       SEC      10.7
# 4    gilber002and       2021       2022       SEC       SEC       5.0
# ..            ...        ...        ...       ...       ...       ...
# 245  sulliv000noa       2024       2025      BigS       SEC      14.5
# 246  hage--000col       2024       2025       IVY       SEC      13.2
# 247  lawren001luk       2024       2025       MVC       SEC       8.4
# 248  hensel000wya       2024       2025       IVY       SEC      11.4
# 249  kaczma000hen       2024       2025      BTen       SEC      11.3
#
#      next BB%  prev K%  next K%  prev OBP  ...  prev SLG  next SLG  prev OPS  \
# 0        12.5     20.8     20.9     0.336  ...     0.523     0.595     0.859
# 1        10.8     17.4     14.9     0.369  ...     0.527     0.702     0.896
# 2        10.7     18.5     19.0     0.391  ...     0.425     0.532     0.816
# 3        10.6     19.0     14.9     0.390  ...     0.532     0.531     0.923
# 4        13.5     13.2     13.1     0.341  ...     0.437     0.673     0.778
# ..        ...      ...      ...       ...  ...       ...       ...       ...
# 245      13.7     12.1     16.5     0.453  ...     0.613     0.645     1.066
# 246      11.9     13.7     15.1     0.471  ...     0.658     0.574     1.129
# 247       7.5     13.6     12.7     0.399  ...     0.465     0.425     0.864
# 248       7.5     11.4     16.2     0.465  ...     0.755     0.562     1.220
# 249      10.6     16.6     20.7     0.417  ...     0.476     0.486     0.892
#
#      next OPS  conf jump score  class transition_2 to 3  \
# 0       0.986           0.0099                     True
# 1       1.151           0.0011                     True
# 2       0.923           0.0011                    False
# 3       0.950          -0.0028                    False
# 4       1.128           0.0099                     True
# ..        ...              ...                      ...
# 245     1.120           0.1100                    False
# 246     1.019           0.1274                    False
# 247     0.822           0.0771                     True
# 248     0.985           0.1274                    False
# 249     0.880           0.0526                     True
#
#      class transition_3 to 4  class transition_4 to 5  \
# 0                      False                    False
# 1                      False                    False
# 2                       True                    False
# 3                      False                     True
# 4                      False                    False
# ..                       ...                      ...
# 245                     True                    False
# 246                     True                    False
# 247                    False                    False
# 248                    False                     True
# 249                    False                    False
#
#      class transition_5 to 6  type_Transfer
# 0                      False          False
# 1                      False          False
# 2                      False          False
# 3                      False          False
# 4                      False          False
# ..                       ...            ...
# 245                    False           True
# 246                    False           True
# 247                    False           True
# 248                    False           True
# 249                    False           True
#
# [250 rows x 21 columns]

# %%
df_filt = mreg_df.drop(columns=['player_id','prev year','next year', 'prev conf', 'next conf'])

# %%
df_filt
# Out:
#      prev BB%  next BB%  prev K%  next K%  prev OBP  next OBP  prev SLG  \
# 0         8.3      12.5     20.8     20.9     0.336     0.391     0.523
# 1         9.2      10.8     17.4     14.9     0.369     0.449     0.527
# 2        10.3      10.7     18.5     19.0     0.391     0.390     0.425
# 3        10.7      10.6     19.0     14.9     0.390     0.418     0.532
# 4         5.0      13.5     13.2     13.1     0.341     0.455     0.437
# ..        ...       ...      ...      ...       ...       ...       ...
# 245      14.5      13.7     12.1     16.5     0.453     0.475     0.613
# 246      13.2      11.9     13.7     15.1     0.471     0.444     0.658
# 247       8.4       7.5     13.6     12.7     0.399     0.397     0.465
# 248      11.4       7.5     11.4     16.2     0.465     0.423     0.755
# 249      11.3      10.6     16.6     20.7     0.417     0.394     0.476
#
#      next SLG  prev OPS  next OPS  conf jump score  class transition_2 to 3  \
# 0       0.595     0.859     0.986           0.0099                     True
# 1       0.702     0.896     1.151           0.0011                     True
# 2       0.532     0.816     0.923           0.0011                    False
# 3       0.531     0.923     0.950          -0.0028                    False
# 4       0.673     0.778     1.128           0.0099                     True
# ..        ...       ...       ...              ...                      ...
# 245     0.645     1.066     1.120           0.1100                    False
# 246     0.574     1.129     1.019           0.1274                    False
# 247     0.425     0.864     0.822           0.0771                     True
# 248     0.562     1.220     0.985           0.1274                    False
# 249     0.486     0.892     0.880           0.0526                     True
#
#      class transition_3 to 4  class transition_4 to 5  \
# 0                      False                    False
# 1                      False                    False
# 2                       True                    False
# 3                      False                     True
# 4                      False                    False
# ..                       ...                      ...
# 245                     True                    False
# 246                     True                    False
# 247                    False                    False
# 248                    False                     True
# 249                    False                    False
#
#      class transition_5 to 6  type_Transfer
# 0                      False          False
# 1                      False          False
# 2                      False          False
# 3                      False          False
# 4                      False          False
# ..                       ...            ...
# 245                    False           True
# 246                    False           True
# 247                    False           True
# 248                    False           True
# 249                    False           True
#
# [250 rows x 16 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error

stats = ['BB%', 'K%', 'OBP', 'SLG', 'OPS']

# Columns that are shared across all regressions
shared_features = [
    'conf jump score',
    'class transition_2 to 3',
    'class transition_3 to 4',
    'class transition_4 to 5',
    'class transition_5 to 6',
    'type_Transfer'
]

models = {}

for stat in stats:
    # Set up target and features
    target_col = f'next {stat}'
    prev_col = f'prev {stat}'
    features = [prev_col] + shared_features

    # Drop rows with missing values in relevant columns
    data = df_filt.dropna(subset=[target_col] + features)

    X = data[features]
    y = data[target_col]

    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # Fit regression model
    model = LinearRegression()
    model.fit(X_scaled, y)
    y_pred = model.predict(X)

    
    # Get coefficients
    coefficients = pd.Series(model.coef_, index=features)
    print(coefficients.sort_values(key=abs, ascending=False))

    # Store model and print results
    models[stat] = model
    print(f"\nStat: {stat}")
    print(f"  R²:  {r2_score(y, y_pred):.3f}")
    print(f"  MAE: {mean_absolute_error(y, y_pred):.3f}")

    print(f"\nMultipliers for {stat}:")
    for feature, coef in zip(features, model.coef_):
        print(f"  {feature}: {coef:.4f}")
    print(f"  Intercept: {model.intercept_:.4f}")
# Out:
# prev BB%                   1.622737
# type_Transfer              0.361627
# class transition_5 to 6    0.334154
# class transition_2 to 3    0.327489
# conf jump score           -0.285106
# class transition_3 to 4   -0.149659
# class transition_4 to 5    0.118388
# dtype: float64
#
# Stat: BB%
#   R²:  -29.318
#   MAE: 18.358
#
# Multipliers for BB%:
#   prev BB%: 1.6227
#   conf jump score: -0.2851
#   class transition_2 to 3: 0.3275
#   class transition_3 to 4: -0.1497
#   class transition_4 to 5: 0.1184
#   class transition_5 to 6: 0.3342
#   type_Transfer: 0.3616
#   Intercept: 12.3872
# prev K%                    3.721668
# type_Transfer              0.447613
# class transition_2 to 3    0.385525
# class transition_3 to 4    0.356525
# class transition_4 to 5    0.343598
# conf jump score            0.111917
# class transition_5 to 6    0.003946
# dtype: float64
#
# Stat: K%
#   R²:  -175.400
#   MAE: 70.992
#
# Multipliers for K%:
#   prev K%: 3.7217
#   conf jump score: 0.1119
#   class transition_2 to 3: 0.3855
#   class transition_3 to 4: 0.3565
#   class transition_4 to 5: 0.3436
#   class transition_5 to 6: 0.0039
#   type_Transfer: 0.4476
#   Intercept: 19.1440
# prev OBP                   0.017267
# class transition_2 to 3    0.005198
# class transition_5 to 6    0.002344
# class transition_4 to 5    0.002143
# conf jump score           -0.001577
# type_Transfer             -0.000669
# class transition_3 to 4    0.000497
# dtype: float64
#
# Stat: OBP
#   R²:  -0.026
#   MAE: 0.036
#
# Multipliers for OBP:
#   prev OBP: 0.0173
#   conf jump score: -0.0016
#   class transition_2 to 3: 0.0052
#   class transition_3 to 4: 0.0005
#   class transition_4 to 5: 0.0021
#   class transition_5 to 6: 0.0023
#   type_Transfer: -0.0007
#   Intercept: 0.4037
# prev SLG                   0.067699
# conf jump score           -0.020978
# class transition_5 to 6    0.004017
# class transition_2 to 3   -0.002343
# class transition_3 to 4   -0.002170
# type_Transfer             -0.001690
# class transition_4 to 5   -0.000287
# dtype: float64
#
# Stat: SLG
#   R²:  -0.015
#   MAE: 0.092
#
# Multipliers for SLG:
#   prev SLG: 0.0677
#   conf jump score: -0.0210
#   class transition_2 to 3: -0.0023
#   class transition_3 to 4: -0.0022
#   class transition_4 to 5: -0.0003
#   class transition_5 to 6: 0.0040
#   type_Transfer: -0.0017
#   Intercept: 0.5228
# prev OPS                   0.081691
# conf jump score           -0.025035
# class transition_5 to 6    0.007024
# class transition_2 to 3    0.003797
# class transition_4 to 5    0.002538
# type_Transfer             -0.001621
# class transition_3 to 4   -0.000921
# dtype: float64
#
# Stat: OPS
#   R²:  -0.187
#   MAE: 0.131
#
# Multipliers for OPS:
#   prev OPS: 0.0817
#   conf jump score: -0.0250
#   class transition_2 to 3: 0.0038
#   class transition_3 to 4: -0.0009
#   class transition_4 to 5: 0.0025
#   class transition_5 to 6: 0.0070
#   type_Transfer: -0.0016
#   Intercept: 0.9264
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
